# %%
import pandas as pd
import numpy as np
from xgboost import XGBRegressor
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from pybaseball import statcast, cache
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
import joblib
import math
cache.enable()

# %%
sc_23 = statcast('2023-04-01', '2023-08-16')
# Out:
# This is a large query, it may take a moment to complete
# 100%|████████████████████████████████████████████████████████████████████████████████| 138/138 [01:50<00:00,  1.25it/s]

# %%
columns = ['player_name', 'p_throws', 'pitch_name', 'stand', 'delta_run_exp', 'release_speed', 'release_spin_rate', 'pfx_x', 'pfx_z', 'plate_x', 'plate_z', 'balls', 'strikes', 'release_pos_x', 'release_pos_z', 'spin_axis', 'release_extension']
non_features = ['player_name', 'delta_run_exp', 'stand', 'pitch_name', 'p_throws', 'balls', 'strikes', 'plate_x', 'plate_z']
before_features = [column for column in columns if column not in non_features]
df = sc_23[columns].dropna(subset='delta_run_exp').dropna(subset=before_features)

# %%
capps_constant = 8.2 - df.release_extension.mean()

# %%
df['pfx_x'] = abs(df['pfx_x'])
df.loc[df['p_throws'] == 'L', 'spin_axis'] = 360 - df.loc[df['p_throws'] == 'L', 'spin_axis']
df['release_pos_x'] = abs(df['release_pos_x'])

average_extension = df['release_extension'].mean()
# Found this using the added Carter Capps perceived velo divided by his added extension over average
extension_constant = (3.5/capps_constant)
def calculate_perceived_velocity(row):
    adjusted_extension = row['release_extension'] - average_extension
    perceived_velocity = row['release_speed'] + (adjusted_extension * extension_constant)
    return perceived_velocity

df['perceived_velocity'] = df.apply(calculate_perceived_velocity, axis=1)

# %%
arm_angles = np.degrees(np.arctan2(df['release_pos_z'], df['release_pos_x']))
df['arm_angle'] = arm_angles

# %%
df['spin_axis_rad'] = df['spin_axis'] * np.pi / 180

df['TSM'] = df['release_spin_rate'] * np.sin(df['spin_axis_rad'])
df['G'] = df['release_spin_rate'] * np.cos(df['spin_axis_rad'])

df['spin_efficiency'] = (df['TSM'] / df['release_spin_rate']) * 100

min_spin_efficiency = df['spin_efficiency'].min(skipna=True)
max_spin_efficiency = df['spin_efficiency'].max(skipna=True)

df['normalized_spin_efficiency'] = (df['spin_efficiency'] - min_spin_efficiency) / (max_spin_efficiency - min_spin_efficiency)

# %%
fb_model = joblib.load("models/['4-Seam Fastball', 'Sinker']_optimized_random_stuff.joblib")
bb_model = joblib.load("models/['Curveball', 'Slider', 'Cutter', 'Knuckle Curve', 'Sweeper']_optimized_random_stuff.joblib")
offs_model = joblib.load("models/['Split-Finger', 'Changeup', 'Forkball']_optimized_random_stuff.joblib")

# %%
features = ['pfx_x',
 'pfx_z',
 'release_spin_rate',
 'arm_angle',
 'perceived_velocity',
 'normalized_spin_efficiency']

def predict_pitch(df, pitch_name, model):
    pitch_df = df[df['pitch_name'].isin(pitch_name)]
    X = pitch_df[features].values  # Assuming you have defined 'features'
    pitch_df['xrv'] = model.predict(X)
    return pitch_df

fastball_sc = predict_pitch(df, ['4-Seam Fastball', 'Sinker'], fb_model)
bb_sc = predict_pitch(df, ['Cutter', 'Curveball', 'Knuckle Curve', 'Slider', 'Sweeper', 'Slow Curve'], bb_model)
offs_sc = predict_pitch(df, ['Split-Finger', 'Changeup', 'Forkball'], offs_model)

total_sc = pd.concat([fastball_sc, bb_sc, offs_sc])
# Out:
# C:\Users\kellyjc\AppData\Local\Temp\ipykernel_2152\3503789196.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pitch_df['xrv'] = model.predict(X)
# C:\Users\kellyjc\AppData\Local\Temp\ipykernel_2152\3503789196.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pitch_df['xrv'] = model.predict(X)
# C:\Users\kellyjc\AppData\Local\Temp\ipykernel_2152\3503789196.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pitch_df['xrv'] = model.predict(X)

# %%
def calculate_stuff_plus(pitch_sc, min_num_pitches=100):
    agg_stuff_plus = pitch_sc.groupby(['player_name', 'pitch_name']).agg(
        mean_xrv=('xrv', 'mean'),
        num_pitches=('player_name', 'count'),
        velo=('release_speed', 'mean'),
        perceived_velo=('perceived_velocity', 'mean'),
        spin_rate=('release_spin_rate', 'mean'),
        vert_break=('pfx_z', 'mean'),
        horz_break=('pfx_x', 'mean')
    ).reset_index()

    agg_stuff_plus['xrv_100'] = agg_stuff_plus['mean_xrv'] * 100
    agg_stuff_plus['xrv_100_adj'] = abs(agg_stuff_plus['xrv_100'] - agg_stuff_plus['xrv_100'].max())
    agg_stuff_plus['stuff+'] = (agg_stuff_plus['xrv_100_adj'] / agg_stuff_plus['xrv_100_adj'].mean()) * 100
    agg_stuff_plus = agg_stuff_plus.sort_values('stuff+', ascending=False)

    agg_stuff_plus = agg_stuff_plus[agg_stuff_plus['num_pitches'] > min_num_pitches]

    return agg_stuff_plus

def calculate_agg_stuff_plus(pitch_sc, min_num_pitches=100):
    agg_stuff_plus = pitch_sc.groupby(['player_name']).agg(
        mean_xrv=('xrv', 'mean'),
        num_pitches=('player_name', 'count'),
        velo=('release_speed', 'mean'),
        perceived_velo=('perceived_velocity', 'mean'),
        spin_rate=('release_spin_rate', 'mean'),
        vert_break=('pfx_z', 'mean'),
        horz_break=('pfx_x', 'mean')
    ).reset_index()

    agg_stuff_plus['xrv_100'] = agg_stuff_plus['mean_xrv'] * 100
    agg_stuff_plus['xrv_100_adj'] = abs(agg_stuff_plus['xrv_100'] - agg_stuff_plus['xrv_100'].max())
    agg_stuff_plus['stuff+'] = (agg_stuff_plus['xrv_100_adj'] / agg_stuff_plus['xrv_100_adj'].mean()) * 100
    agg_stuff_plus = agg_stuff_plus.sort_values('stuff+', ascending=False)

    agg_stuff_plus = agg_stuff_plus[agg_stuff_plus['num_pitches'] > min_num_pitches]

    return agg_stuff_plus

agg_fb = calculate_stuff_plus(fastball_sc, 100)
agg_bb = calculate_stuff_plus(bb_sc, 100)
agg_offs = calculate_stuff_plus(offs_sc, 50)
agg_total = calculate_agg_stuff_plus(total_sc, 700)

# %%
pd.set_option('display.max_rows', None)
agg_fb
# Out:
#                 player_name       pitch_name  mean_xrv  num_pitches  \
# 69          Bautista, Félix  4-Seam Fastball -0.016352          645
# 401           Helsley, Ryan  4-Seam Fastball -0.011817          221
# 278         Fairbanks, Pete  4-Seam Fastball -0.011789          195
# 952        Strider, Spencer  4-Seam Fastball -0.010972         1366
# 847          Romano, Jordan  4-Seam Fastball -0.010505          279
# 171        Chapman, Aroldis  4-Seam Fastball -0.010153          376
# 275       Estrada, Jeremiah  4-Seam Fastball -0.009726          199
# 794             Pérez, Eury  4-Seam Fastball -0.009521          466
# 377             Hader, Josh           Sinker -0.009273          530
# 151           Cano, Yennier           Sinker -0.009215          449
# 1129          deGrom, Jacob  4-Seam Fastball -0.009151          188
# 780           Pivetta, Nick  4-Seam Fastball -0.009021          907
# 921            Snell, Blake  4-Seam Fastball -0.009014         1102
# 752        Palencia, Daniel  4-Seam Fastball -0.008072          146
# 670           Miller, Mason  4-Seam Fastball -0.007963          198
# 107            Bradley, Taj  4-Seam Fastball -0.007473          589
# 656          Megill, Trevor  4-Seam Fastball -0.007397          231
# 431           Hoffman, Jeff  4-Seam Fastball -0.007321          203
# 478            Jiménez, Joe  4-Seam Fastball -0.007107          451
# 414       Hernández, Carlos  4-Seam Fastball -0.007083          541
# 351          Glasnow, Tyler  4-Seam Fastball -0.007034          515
# 73            Bednar, David  4-Seam Fastball -0.006642          438
# 815         Rasmussen, Drew  4-Seam Fastball -0.006502          196
# 534         Kopech, Michael  4-Seam Fastball -0.006410         1289
# 172        Chapman, Aroldis           Sinker -0.006196          104
# 751           Pagán, Emilio  4-Seam Fastball -0.006000          417
# 421           Hicks, Jordan           Sinker -0.005854          478
# 1091         Wilson, Steven  4-Seam Fastball -0.005822          302
# 937            Stanek, Ryne  4-Seam Fastball -0.005752          464
# 165            Cease, Dylan  4-Seam Fastball -0.005699         1002
# 930           Soto, Gregory           Sinker -0.005652          291
# 764           Pearson, Nate  4-Seam Fastball -0.005611          425
# 825        Richards, Trevor  4-Seam Fastball -0.005565          414
# 609            Mahle, Tyler  4-Seam Fastball -0.005549          212
# 888           Scott, Tanner  4-Seam Fastball -0.005165          419
# 500              Kelly, Joe           Sinker -0.005146          167
# 736              Ort, Kaleb  4-Seam Fastball -0.005116          258
# 882             Sborz, Josh  4-Seam Fastball -0.005086          247
# 634             May, Dustin           Sinker -0.005064          226
# 1031            Vesia, Alex  4-Seam Fastball -0.004948          418
# 846           Rogers, Tyler           Sinker -0.004942          409
# 666           Miller, Bobby  4-Seam Fastball -0.004933          302
# 164          Castro, Miguel           Sinker -0.004770          299
# 1110      Woodruff, Brandon  4-Seam Fastball -0.004766          150
# 6              Abreu, Bryan  4-Seam Fastball -0.004614          381
# 193            Cole, Gerrit  4-Seam Fastball -0.004568         1285
# 915             Smith, Drew  4-Seam Fastball -0.004526          477
# 660    Merryweather, Julian  4-Seam Fastball -0.004489          375
# 11              Adam, Jason  4-Seam Fastball -0.004487          257
# 620           Marte, Yunior           Sinker -0.004457          305
# 376            Guerra, Javy           Sinker -0.004415          118
# 556        Lawrence, Justin           Sinker -0.004377          439
# 138              Bush, Matt  4-Seam Fastball -0.004339          101
# 48             Baker, Bryan  4-Seam Fastball -0.004224          417
# 179            Cimber, Adam           Sinker -0.004180          107
# 1061            Webb, Jacob  4-Seam Fastball -0.004145          298
# 782            Poche, Colin  4-Seam Fastball -0.004125          433
# 490        Karinchak, James  4-Seam Fastball -0.004088          271
# 833      Rodriguez, Grayson  4-Seam Fastball -0.004032          678
# 359         Gore, MacKenzie  4-Seam Fastball -0.003978         1250
# 811          Ramirez, Yohan           Sinker -0.003928          374
# 251   Domínguez, Seranthony           Sinker -0.003898          194
# 371          Greene, Hunter  4-Seam Fastball -0.003877          685
# 1083        Williams, Gavin  4-Seam Fastball -0.003871          523
# 1082        Williams, Devin  4-Seam Fastball -0.003843          307
# 417     Hernández, Jonathan           Sinker -0.003784          173
# 20         Alcantara, Sandy           Sinker -0.003728          631
# 68            Baumann, Mike  4-Seam Fastball -0.003718          516
# 174            Chargois, JT           Sinker -0.003690          233
# 427               Hill, Tim           Sinker -0.003685          272
# 1046           Walker, Josh  4-Seam Fastball -0.003638          143
# 202          Cordero, Jimmy           Sinker -0.003614          359
# 247           Diekman, Jake  4-Seam Fastball -0.003610          404
# 260            Duran, Jhoan  4-Seam Fastball -0.003583          347
# 644       McClanahan, Shane  4-Seam Fastball -0.003567          714
# 1052          Wantz, Andrew  4-Seam Fastball -0.003559          148
# 604         López, Reynaldo  4-Seam Fastball -0.003558          557
# 302            Foley, Jason           Sinker -0.003532          556
# 93            Blanco, Ronel  4-Seam Fastball -0.003531          354
# 498          Kelley, Trevor           Sinker -0.003519          124
# 749           Oviedo, Johan           Sinker -0.003484          118
# 27           Almonte, Yency           Sinker -0.003425          205
# 304         Francis, Bowden  4-Seam Fastball -0.003421          159
# 327            García, Yimi           Sinker -0.003379          143
# 276         Estévez, Carlos  4-Seam Fastball -0.003354          534
# 999            Topa, Justin           Sinker -0.003321          330
# 223              Cuas, Jose           Sinker -0.003310          383
# 113           Brebbia, John  4-Seam Fastball -0.003302          207
# 783               Pop, Zach           Sinker -0.003280          109
# 516          Kikuchi, Yusei  4-Seam Fastball -0.003249          966
# 34          Anderson, Grant           Sinker -0.003234          139
# 668           Miller, Bryce  4-Seam Fastball -0.003190          901
# 462          Jackson, Andre  4-Seam Fastball -0.003162          186
# 1026       Velasquez, Vince  4-Seam Fastball -0.003040          265
# 601            López, Jorge           Sinker -0.003032          232
# 519          Kimbrel, Craig  4-Seam Fastball -0.002999          548
# 218        Crochet, Garrett  4-Seam Fastball -0.002998          150
# 606         Machado, Andrés           Sinker -0.002997          137
# 724        Nogosek, Stephen  4-Seam Fastball -0.002981          306
# 1074          Wheeler, Zack           Sinker -0.002958          434
# 994          Thompson, Ryan           Sinker -0.002917          147
# 432        Holderman, Colin           Sinker -0.002915          327
# 230             Darvish, Yu  4-Seam Fastball -0.002877          333
# 442           Houck, Tanner           Sinker -0.002867          263
# 391          Harvey, Hunter  4-Seam Fastball -0.002853          392
# 1073          Wheeler, Zack  4-Seam Fastball -0.002830          993
# 469            Jacques, Joe           Sinker -0.002826          205
# 162          Castillo, Luis           Sinker -0.002791          389
# 944          Stewart, Brock  4-Seam Fastball -0.002782          151
# 214        Crawford, Kutter  4-Seam Fastball -0.002777          560
# 28           Alvarado, José           Sinker -0.002717          259
# 980          Tarnok, Freddy  4-Seam Fastball -0.002640          148
# 938          Staumont, Josh  4-Seam Fastball -0.002560          167
# 679            Minter, A.J.  4-Seam Fastball -0.002548          360
# 502            Kelly, Kevin           Sinker -0.002544          398
# 250   Domínguez, Seranthony  4-Seam Fastball -0.002528          221
# 770          Perdomo, Angel  4-Seam Fastball -0.002528          293
# 713           Nardi, Andrew  4-Seam Fastball -0.002491          387
# 766         Peralta, Freddy  4-Seam Fastball -0.002469         1139
# 661       Middleton, Keynan  4-Seam Fastball -0.002434          192
# 560              Lee, Dylan  4-Seam Fastball -0.002429          119
# 325            García, Luis           Sinker -0.002406          288
# 583             Loup, Aaron           Sinker -0.002389          325
# 273            Erceg, Lucas           Sinker -0.002324          226
# 654            Medina, Luis  4-Seam Fastball -0.002294          637
# 914             Smith, Chad           Sinker -0.002245          133
# 907             Sims, Lucas  4-Seam Fastball -0.002232          336
# 1106             Woo, Bryan           Sinker -0.002223          235
# 321            Garcia, Rico  4-Seam Fastball -0.002205          148
# 667           Miller, Bobby           Sinker -0.002196          295
# 558           Leclerc, José  4-Seam Fastball -0.002162          240
# 318             Gallen, Zac  4-Seam Fastball -0.002132         1099
# 363       Graterol, Brusdar           Sinker -0.002063          317
# 992         Thompson, Mason           Sinker -0.002047          439
# 671          Miller, Shelby  4-Seam Fastball -0.002022          262
# 112       Brazoban, Huascar           Sinker -0.001983          203
# 765          Peguero, Elvis           Sinker -0.001973          365
# 116           Brieske, Beau  4-Seam Fastball -0.001903          102
# 375            Guerra, Javy  4-Seam Fastball -0.001895          125
# 617         Marinaccio, Ron  4-Seam Fastball -0.001838          420
# 929           Soto, Gregory  4-Seam Fastball -0.001826          140
# 178            Cimber, Adam  4-Seam Fastball -0.001785          145
# 335          Gausman, Kevin  4-Seam Fastball -0.001783         1140
# 879         Santos, Gregory           Sinker -0.001780          392
# 358        González, Victor           Sinker -0.001775          236
# 430           Hoeing, Bryan           Sinker -0.001752          348
# 426               Hill, Tim  4-Seam Fastball -0.001723          310
# 252           Doval, Camilo           Sinker -0.001670          251
# 380           Hamilton, Ian           Sinker -0.001615          160
# 864        Salazar, Eduardo           Sinker -0.001593          121
# 730          Ohtani, Shohei  4-Seam Fastball -0.001584          645
# 887         Schreiber, John           Sinker -0.001574          139
# 655            Medina, Luis           Sinker -0.001568          163
# 121            Brito, Jhony           Sinker -0.001557          338
# 677            Milner, Hoby           Sinker -0.001491          235
# 742          Ortiz, Luis L.           Sinker -0.001491          251
# 708           Muñoz, Andrés  4-Seam Fastball -0.001451          151
# 400             Heller, Ben           Sinker -0.001448          112
# 949            Strahm, Matt           Sinker -0.001406          218
# 109           Brasier, Ryan  4-Seam Fastball -0.001379          251
# 1069           Wells, Tyler  4-Seam Fastball -0.001350          681
# 784           Pressly, Ryan  4-Seam Fastball -0.001349          176
# 698         Morton, Charlie           Sinker -0.001329          159
# 83           Bickford, Phil  4-Seam Fastball -0.001324          621
# 633             May, Dustin  4-Seam Fastball -0.001297          158
# 143         Cabrera, Edward           Sinker -0.001270          136
# 261            Díaz, Alexis  4-Seam Fastball -0.001202          429
# 123           Brown, Hunter  4-Seam Fastball -0.001198          920
# 744          Ottavino, Adam           Sinker -0.001193          293
# 122         Brogdon, Connor  4-Seam Fastball -0.001183          165
# 943      Stephenson, Robert  4-Seam Fastball -0.001131          150
# 552             Lange, Alex           Sinker -0.001080          253
# 108             Brash, Matt  4-Seam Fastball -0.001068          364
# 77            Bello, Brayan           Sinker -0.001050          672
# 142         Cabrera, Edward  4-Seam Fastball -0.000978          393
# 147        Campbell, Isaiah  4-Seam Fastball -0.000976          120
# 659             Mejía, J.C.           Sinker -0.000962          118
# 1030      Verlander, Justin  4-Seam Fastball -0.000955          874
# 1014          Urquidy, José  4-Seam Fastball -0.000841          209
# 341          Gilbert, Logan  4-Seam Fastball -0.000831          931
# 1087       Willingham, Amos  4-Seam Fastball -0.000807          178
# 573            Lodolo, Nick  4-Seam Fastball -0.000807          296
# 564          Leone, Dominic  4-Seam Fastball -0.000795          221
# 527           Kirby, George           Sinker -0.000772          477
# 605         Machado, Andrés  4-Seam Fastball -0.000758          138
# 189         Clevinger, Mike  4-Seam Fastball -0.000748          643
# 523           King, Michael           Sinker -0.000745          289
# 926           Soriano, José           Sinker -0.000741          129
# 763           Payamps, Joel           Sinker -0.000730          191
# 989         Thielbar, Caleb  4-Seam Fastball -0.000728          126
# 1117       Yacabonis, Jimmy           Sinker -0.000716          151
# 5             Abreu, Albert           Sinker -0.000716          493
# 181           Cisnero, José           Sinker -0.000714          144
# 1013           Uribe, Abner           Sinker -0.000707          142
# 396           Hearn, Taylor  4-Seam Fastball -0.000689          119
# 428            Hjelle, Sean           Sinker -0.000664          166
# 686         Montero, Rafael           Sinker -0.000643          137
# 365       Graveman, Kendall           Sinker -0.000637          343
# 776          Phillips, Evan  4-Seam Fastball -0.000625          128
# 720            Nelson, Ryne  4-Seam Fastball -0.000607         1090
# 841           Rodón, Carlos  4-Seam Fastball -0.000573          317
# 390          Hartwig, Grant           Sinker -0.000474          174
# 990        Thompson, Keegan  4-Seam Fastball -0.000474          164
# 338             Gibaut, Ian  4-Seam Fastball -0.000459          384
# 894            Senga, Kodai  4-Seam Fastball -0.000431          781
# 82            Bibee, Tanner  4-Seam Fastball -0.000426          855
# 868           Sandlin, Nick           Sinker -0.000401          129
# 238           De León, José  4-Seam Fastball -0.000395          148
# 361            Gott, Trevor           Sinker -0.000353          178
# 118           Brigham, Jeff  4-Seam Fastball -0.000328          186
# 310      Fujinami, Shintaro  4-Seam Fastball -0.000327          605
# 769          Peralta, Wandy           Sinker -0.000314          274
# 461             Irvin, Jake           Sinker -0.000306          434
# 790               Puk, A.J.  4-Seam Fastball -0.000291          349
# 38          Anderson, Tyler           Sinker -0.000285          107
# 301            Floro, Dylan           Sinker -0.000267          237
# 291         Ferrer, Jose A.  4-Seam Fastball -0.000233          200
# 839        Rodríguez, Yerry  4-Seam Fastball -0.000223          130
# 395          Heaney, Andrew  4-Seam Fastball -0.000215         1156
# 883           Scherzer, Max  4-Seam Fastball -0.000202          907
# 748           Oviedo, Johan  4-Seam Fastball -0.000168          807
# 203          Cortes, Nestor  4-Seam Fastball -0.000138          555
# 240    De Los Santos, Yerry           Sinker -0.000132          245
# 1035           Voth, Austin  4-Seam Fastball -0.000128          262
# 324            García, Luis  4-Seam Fastball -0.000122          120
# 561         Legumina, Casey  4-Seam Fastball -0.000097          141
# 379           Hamilton, Ian  4-Seam Fastball -0.000066          179
# 47             Bachman, Sam           Sinker -0.000059          114
# 629        Martínez, Adrián           Sinker -0.000054          318
# 1047           Walker, Ryan           Sinker -0.000005          376
# 41         Armstrong, Shawn           Sinker  0.000011          154
# 346           Ginkel, Kevin  4-Seam Fastball  0.000030          343
# 194          Coleman, Dylan  4-Seam Fastball  0.000039          121
# 293          Finnegan, Kyle  4-Seam Fastball  0.000048          564
# 978          Tapia, Domingo  4-Seam Fastball  0.000069          139
# 805            Ragans, Cole  4-Seam Fastball  0.000088          331
# 726             Nola, Aaron           Sinker  0.000111          450
# 290         Ferguson, Caleb  4-Seam Fastball  0.000130          509
# 901          Sheehan, Emmet  4-Seam Fastball  0.000176          369
# 326            García, Yimi  4-Seam Fastball  0.000185          253
# 144        Cabrera, Génesis  4-Seam Fastball  0.000197          227
# 635             May, Trevor  4-Seam Fastball  0.000228          221
# 731          Ohtani, Shohei           Sinker  0.000240          124
# 881         Saucedo, Tayler           Sinker  0.000250          227
# 474        Javier, Cristian  4-Seam Fastball  0.000272         1206
# 67      Battenfield, Peyton  4-Seam Fastball  0.000282          245
# 272            Erceg, Lucas  4-Seam Fastball  0.000283          177
# 466           Jackson, Zach  4-Seam Fastball  0.000285          207
# 40         Armstrong, Shawn  4-Seam Fastball  0.000292          113
# 285         Faucher, Calvin           Sinker  0.000294          148
# 538            Kremer, Dean  4-Seam Fastball  0.000336          781
# 648          McGough, Scott  4-Seam Fastball  0.000337          488
# 312         Fulmer, Michael  4-Seam Fastball  0.000367          228
# 733             Oller, Adam  4-Seam Fastball  0.000370          186
# 497           Keller, Mitch           Sinker  0.000389          527
# 616           Mantiply, Joe           Sinker  0.000406          118
# 1075         White, Brendan  4-Seam Fastball  0.000409          162
# 762           Payamps, Joel  4-Seam Fastball  0.000447          182
# 1023         Varland, Louie  4-Seam Fastball  0.000450          388
# 735            Olson, Reese           Sinker  0.000470          186
# 935            Speier, Gabe           Sinker  0.000487          265
# 3              Abbott, Cory  4-Seam Fastball  0.000506          219
# 942         Stephan, Trevor  4-Seam Fastball  0.000520          400
# 61            Barria, Jaime  4-Seam Fastball  0.000521          336
# 897          Severino, Luis  4-Seam Fastball  0.000526          600
# 694             Morgan, Eli  4-Seam Fastball  0.000557          326
# 721           Neris, Hector  4-Seam Fastball  0.000668          380
# 1090          Wilson, Bryse           Sinker  0.000679          307
# 672           Miller, Tyson  4-Seam Fastball  0.000703          119
# 231             Darvish, Yu           Sinker  0.000729          377
# 802           Quijada, José  4-Seam Fastball  0.000771          132
# 134            Burke, Brock  4-Seam Fastball  0.000806          435
# 950         Stratton, Chris  4-Seam Fastball  0.000819          552
# 958       Strzelecki, Peter           Sinker  0.000837          123
# 685         Montero, Rafael  4-Seam Fastball  0.000847          418
# 676            Milner, Hoby  4-Seam Fastball  0.000868          170
# 386           Harris, Hogan  4-Seam Fastball  0.000870          484
# 856              Ruiz, José  4-Seam Fastball  0.000871          246
# 975     Sánchez, Cristopher           Sinker  0.000891          422
# 543              Kuhl, Chad           Sinker  0.000899          268
# 572       Llovera, Mauricio           Sinker  0.000910          104
# 603            López, Pablo           Sinker  0.000917          220
# 610            Manaea, Sean  4-Seam Fastball  0.000924          800
# 1095       Winckowski, Josh           Sinker  0.000927          351
# 602            López, Pablo  4-Seam Fastball  0.000934          785
# 267             Eflin, Zach           Sinker  0.000949          622
# 1081      Whitlock, Garrett           Sinker  0.000962          450
# 29          Alzolay, Adbert  4-Seam Fastball  0.001008          187
# 598             Lynn, Lance  4-Seam Fastball  0.001015          988
# 510            Kennedy, Ian  4-Seam Fastball  0.001032          133
# 773         Pfaadt, Brandon  4-Seam Fastball  0.001045          435
# 971           Swanson, Erik  4-Seam Fastball  0.001054          275
# 1001       Toussaint, Touki           Sinker  0.001055          205
# 1089          Wilson, Bryse  4-Seam Fastball  0.001056          147
# 890           Scott, Tayler           Sinker  0.001062          107
# 621           Martin, Chris  4-Seam Fastball  0.001065          176
# 264       Edwards Jr., Carl  4-Seam Fastball  0.001070          354
# 364       Graveman, Kendall  4-Seam Fastball  0.001094          154
# 37          Anderson, Tyler  4-Seam Fastball  0.001098          694
# 180           Cisnero, José  4-Seam Fastball  0.001102          297
# 348          Giolito, Lucas  4-Seam Fastball  0.001111         1071
# 948            Strahm, Matt  4-Seam Fastball  0.001114          466
# 522           King, Michael  4-Seam Fastball  0.001119          217
# 1054         Ward, Thaddeus           Sinker  0.001122          212
# 271         Eovaldi, Nathan  4-Seam Fastball  0.001125          682
# 72            Beck, Tristan  4-Seam Fastball  0.001132          338
# 592          Luzardo, Jesús  4-Seam Fastball  0.001133          992
# 793           Pérez, Cionel           Sinker  0.001140          184
# 436            Holmes, Clay           Sinker  0.001153          512
# 297           Fleming, Josh           Sinker  0.001168          330
# 899            Sewald, Paul  4-Seam Fastball  0.001206          395
# 19         Alcantara, Sandy  4-Seam Fastball  0.001217          482
# 657           Megill, Tylor  4-Seam Fastball  0.001221          794
# 337         Germán, Domingo           Sinker  0.001244          174
# 418             Herrin, Tim  4-Seam Fastball  0.001250          187
# 865             Sale, Chris  4-Seam Fastball  0.001252          471
# 925           Soriano, José  4-Seam Fastball  0.001294          104
# 613            Manoah, Alek  4-Seam Fastball  0.001305          444
# 294          Flaherty, Jack  4-Seam Fastball  0.001308          897
# 81            Berríos, José           Sinker  0.001309          637
# 1123         Zastryzny, Rob  4-Seam Fastball  0.001347          116
# 85            Bido, Osvaldo           Sinker  0.001349          168
# 547          Lambert, Jimmy  4-Seam Fastball  0.001353          254
# 850            Romero, JoJo           Sinker  0.001376          150
# 614            Manoah, Alek           Sinker  0.001383          449
# 488       Kaprielian, James           Sinker  0.001401          152
# 471           Jameson, Drey           Sinker  0.001421          184
# 1043         Waldichuk, Ken  4-Seam Fastball  0.001433         1009
# 513        Kershaw, Clayton  4-Seam Fastball  0.001447          571
# 226          Curry, Xzavion  4-Seam Fastball  0.001449          507
# 16             Akin, Keegan  4-Seam Fastball  0.001456          258
# 217        Criswell, Cooper           Sinker  0.001468          159
# 496           Keller, Mitch  4-Seam Fastball  0.001472          601
# 1063            Webb, Logan           Sinker  0.001482          814
# 984          Teheran, Julio           Sinker  0.001523          356
# 612           Manning, Matt  4-Seam Fastball  0.001531          430
# 407            Hentges, Sam  4-Seam Fastball  0.001574          190
# 722           Neris, Hector           Sinker  0.001609          141
# 84            Bido, Osvaldo  4-Seam Fastball  0.001625          212
# 227           Curtiss, John  4-Seam Fastball  0.001686          158
# 761           Paxton, James  4-Seam Fastball  0.001722          777
# 131           Bummer, Aaron           Sinker  0.001734          386
# 600            López, Jorge  4-Seam Fastball  0.001741          105
# 329           Garrett, Amir           Sinker  0.001752          151
# 192              Cobb, Alex           Sinker  0.001755          815
# 75         Bellatti, Andrew  4-Seam Fastball  0.001759          129
# 1065          Weems, Jordan  4-Seam Fastball  0.001768          294
# 681      Mlodzinski, Carmen  4-Seam Fastball  0.001779          204
# 309             Frías, Luis  4-Seam Fastball  0.001847          109
# 470           Jameson, Drey  4-Seam Fastball  0.001848          168
# 741          Ortiz, Luis L.  4-Seam Fastball  0.001848          224
# 1018        Valdez, Framber           Sinker  0.001850         1008
# 829         Robertson, Nick  4-Seam Fastball  0.001856          144
# 475            Jax, Griffin  4-Seam Fastball  0.001859          155
# 639              Mayza, Tim           Sinker  0.001859          449
# 314          Gaddis, Hunter  4-Seam Fastball  0.001877          157
# 618             Marsh, Alec  4-Seam Fastball  0.001880          274
# 917       Smith-Shawver, AJ  4-Seam Fastball  0.001899          217
# 1072       Wesneski, Hayden           Sinker  0.001903          222
# 374          Grove, Michael  4-Seam Fastball  0.001922          411
# 625          Martinez, Nick  4-Seam Fastball  0.001936          145
# 539            Kremer, Dean           Sinker  0.001940          339
# 242     DeSclafani, Anthony           Sinker  0.001951          427
# 102          Bradford, Cody  4-Seam Fastball  0.001969          381
# 691           Moran, Jovani  4-Seam Fastball  0.001977          341
# 320            Garcia, Luis  4-Seam Fastball  0.002001          144
# 684               Moll, Sam           Sinker  0.002041          293
# 905          Silseth, Chase  4-Seam Fastball  0.002058          228
# 444          Houser, Adrian           Sinker  0.002074          649
# 688      Montgomery, Jordan           Sinker  0.002092          940
# 689             Moore, Matt  4-Seam Fastball  0.002093          264
# 809           Ramirez, Nick           Sinker  0.002115          222
# 693           Moreta, Dauri  4-Seam Fastball  0.002129          214
# 581       Lorenzen, Michael           Sinker  0.002169          209
# 30          Alzolay, Adbert           Sinker  0.002193          137
# 854         Rucker, Michael  4-Seam Fastball  0.002201          273
# 511               Kerr, Ray  4-Seam Fastball  0.002225          123
# 814         Ramírez, Erasmo           Sinker  0.002257          204
# 521              King, John           Sinker  0.002269          165
# 580       Lorenzen, Michael  4-Seam Fastball  0.002273          618
# 161          Castillo, Luis  4-Seam Fastball  0.002298          959
# 49        Balazovic, Jordan  4-Seam Fastball  0.002329          155
# 460             Irvin, Jake  4-Seam Fastball  0.002348          600
# 626          Martinez, Nick           Sinker  0.002392          266
# 196       Contreras, Roansy  4-Seam Fastball  0.002392          459
# 54             Bard, Daniel           Sinker  0.002395          257
# 526           Kirby, George  4-Seam Fastball  0.002402          860
# 96             Bolton, Cody  4-Seam Fastball  0.002411          140
# 976        Taillon, Jameson  4-Seam Fastball  0.002455          607
# 1105             Woo, Bryan  4-Seam Fastball  0.002481          441
# 184          Clarke, Taylor  4-Seam Fastball  0.002486          244
# 754         Pallante, Andre  4-Seam Fastball  0.002494          479
# 1119           Yates, Kirby  4-Seam Fastball  0.002496          420
# 163           Castillo, Max  4-Seam Fastball  0.002504          135
# 909           Skubal, Tarik  4-Seam Fastball  0.002512          220
# 697         Morton, Charlie  4-Seam Fastball  0.002514          742
# 26           Almonte, Yency  4-Seam Fastball  0.002515          126
# 222              Cuas, Jose  4-Seam Fastball  0.002518          145
# 807           Raley, Brooks           Sinker  0.002608          188
# 734            Olson, Reese  4-Seam Fastball  0.002653          301
# 632            Matz, Steven           Sinker  0.002661         1020
# 152          Carasiti, Matt           Sinker  0.002665          236
# 732           Okert, Steven  4-Seam Fastball  0.002676          285
# 818              Rea, Colin           Sinker  0.002683          455
# 78      Bernardino, Brennan           Sinker  0.002686          380
# 1121            Young, Alex           Sinker  0.002690          257
# 80            Berríos, José  4-Seam Fastball  0.002721          480
# 58             Barnes, Matt  4-Seam Fastball  0.002735          182
# 111       Brazoban, Huascar  4-Seam Fastball  0.002741          169
# 303            France, J.P.  4-Seam Fastball  0.002748          659
# 177         Chirinos, Yonny           Sinker  0.002751          593
# 1038         Wacha, Michael  4-Seam Fastball  0.002764          447
# 463            Jackson, Jay  4-Seam Fastball  0.002770          111
# 1016           Urías, Julio  4-Seam Fastball  0.002791          675
# 792           Pérez, Cionel  4-Seam Fastball  0.002824          215
# 1034             Vest, Will  4-Seam Fastball  0.002826          272
# 22         Alexander, Tyler  4-Seam Fastball  0.002826          189
# 98          Boxberger, Brad  4-Seam Fastball  0.002835          133
# 125          Bruihl, Justin           Sinker  0.002849          129
# 182           Civale, Aaron  4-Seam Fastball  0.002850          176
# 394         Headrick, Brent  4-Seam Fastball  0.002852          208
# 947            Stoudt, Levi  4-Seam Fastball  0.002859          106
# 546           La Sorsa, Joe           Sinker  0.002882          184
# 842          Rogers, Taylor           Sinker  0.002892          248
# 52            Banks, Tanner  4-Seam Fastball  0.002910          242
# 221          Cruz, Fernando  4-Seam Fastball  0.002933          274
# 867           Sandlin, Nick  4-Seam Fastball  0.002947          179
# 591              Lugo, Seth           Sinker  0.002947          284
# 170          Chafin, Andrew           Sinker  0.002994          295
# 331        Garrett, Braxton           Sinker  0.003030          558
# 772         Peterson, David           Sinker  0.003035          276
# 584       Lovelady, Richard  4-Seam Fastball  0.003047          117
# 998         Tonkin, Michael           Sinker  0.003050          550
# 289           Feltner, Ryan           Sinker  0.003061          118
# 703           Murphy, Chris  4-Seam Fastball  0.003101          229
# 1107             Wood, Alex           Sinker  0.003105          572
# 596        Lynch IV, Daniel  4-Seam Fastball  0.003117          344
# 25             Allen, Logan  4-Seam Fastball  0.003118          741
# 577               Long, Sam  4-Seam Fastball  0.003139          370
# 277             Faedo, Alex  4-Seam Fastball  0.003144          356
# 339            Gibson, Kyle  4-Seam Fastball  0.003147          302
# 554              Law, Derek  4-Seam Fastball  0.003158          138
# 384              Hand, Brad           Sinker  0.003171          138
# 90                Blach, Ty           Sinker  0.003180          310
# 858               Ryan, Joe  4-Seam Fastball  0.003185         1190
# 923          Solomon, Peter  4-Seam Fastball  0.003195          129
# 725             Nola, Aaron  4-Seam Fastball  0.003201          625
# 977        Taillon, Jameson           Sinker  0.003208          206
# 56            Barlow, Scott  4-Seam Fastball  0.003217          192
# 843          Rogers, Trevor  4-Seam Fastball  0.003225          142
# 687      Montgomery, Jordan  4-Seam Fastball  0.003245          215
# 334           Garza, Justin           Sinker  0.003269          161
# 1003      Turnbull, Spencer           Sinker  0.003271          106
# 136          Burnes, Corbin           Sinker  0.003274          192
# 504          Kelly, Merrill           Sinker  0.003277          246
# 1058         Weathers, Ryan  4-Seam Fastball  0.003284          501
# 317      Gallegos, Giovanny  4-Seam Fastball  0.003285          364
# 479         Johnson, Pierce  4-Seam Fastball  0.003316          331
# 236             Davis, Noah           Sinker  0.003319          199
# 239    De Los Santos, Enyel  4-Seam Fastball  0.003321          489
# 908           Singer, Brady           Sinker  0.003322         1146
# 126             Bubic, Kris  4-Seam Fastball  0.003436          101
# 360            Gott, Trevor  4-Seam Fastball  0.003440          153
# 946            Stone, Gavin  4-Seam Fastball  0.003442          107
# 175           Chavez, Jesse           Sinker  0.003471          134
# 637            Mayers, Mike  4-Seam Fastball  0.003473          141
# 970          Suárez, Ranger           Sinker  0.003476          451
# 234            Davies, Zach           Sinker  0.003496          384
# 1002      Turnbull, Spencer  4-Seam Fastball  0.003527          227
# 957       Strzelecki, Peter  4-Seam Fastball  0.003530          206
# 212             Cox, Austin  4-Seam Fastball  0.003537          241
# 66           Bassitt, Chris           Sinker  0.003538          905
# 886         Schreiber, John  4-Seam Fastball  0.003633          116
# 663          Mikolas, Miles           Sinker  0.003641          614
# 981            Taylor, Josh  4-Seam Fastball  0.003671          126
# 441           Houck, Tanner  4-Seam Fastball  0.003671          121
# 871             Sands, Cole  4-Seam Fastball  0.003676          101
# 279          Falter, Bailey  4-Seam Fastball  0.003723          445
# 336         Germán, Domingo  4-Seam Fastball  0.003749          458
# 206           Cosgrove, Tom           Sinker  0.003754          118
# 928         Soroka, Michael           Sinker  0.003794          114
# 482            Junis, Jakob           Sinker  0.003808          293
# 959            Suarez, José  4-Seam Fastball  0.003834          184
# 340            Gibson, Kyle           Sinker  0.003841          554
# 927         Soroka, Michael  4-Seam Fastball  0.003843          150
# 455        Iglesias, Raisel  4-Seam Fastball  0.003870          182
# 729            Ober, Bailey  4-Seam Fastball  0.003871          830
# 42         Ashcraft, Graham           Sinker  0.003873          202
# 53             Bard, Daniel  4-Seam Fastball  0.003894          103
# 1010            Ureña, José  4-Seam Fastball  0.003915          126
# 493            Kay, Anthony  4-Seam Fastball  0.003960          102
# 288           Feltner, Ryan  4-Seam Fastball  0.004028          163
# 368            Gray, Josiah           Sinker  0.004031          286
# 857              Ruiz, José           Sinker  0.004043          166
# 550         Lamet, Dinelson           Sinker  0.004076          165
# 884         Schmidt, Clarke           Sinker  0.004077          468
# 664             Miley, Wade  4-Seam Fastball  0.004081          266
# 568           Littell, Zack  4-Seam Fastball  0.004085          276
# 140             Butto, José  4-Seam Fastball  0.004101          144
# 241     DeSclafani, Anthony  4-Seam Fastball  0.004123          191
# 95          Bleier, Richard           Sinker  0.004135          191
# 200         Corbin, Patrick           Sinker  0.004143          906
# 1049        Walker, Taijuan           Sinker  0.004144          520
# 86            Bieber, Shane  4-Seam Fastball  0.004149          588
# 246         Devenski, Chris  4-Seam Fastball  0.004158          163
# 300            Floro, Dylan  4-Seam Fastball  0.004160          246
# 549         Lamet, Dinelson  4-Seam Fastball  0.004169          137
# 156        Carrasco, Carlos           Sinker  0.004251          138
# 2            Abbott, Andrew  4-Seam Fastball  0.004256          620
# 439        Honeywell, Brent  4-Seam Fastball  0.004263          401
# 662          Mikolas, Miles  4-Seam Fastball  0.004299          543
# 529           Kluber, Corey           Sinker  0.004300          230
# 1085       Williams, Trevor           Sinker  0.004304          280
# 369             Gray, Sonny  4-Seam Fastball  0.004306          540
# 99            Boyd, Matthew  4-Seam Fastball  0.004311          455
# 43            Assad, Javier  4-Seam Fastball  0.004315          200
# 1059           Weaver, Luke  4-Seam Fastball  0.004338          774
# 492         Kauffmann, Karl           Sinker  0.004343          121
# 628          Martinez, Seth           Sinker  0.004345          118
# 259           Dunning, Dane           Sinker  0.004355          643
# 1048        Walker, Taijuan  4-Seam Fastball  0.004399          353
# 298           Flexen, Chris  4-Seam Fastball  0.004442          404
# 232        Davidson, Tucker  4-Seam Fastball  0.004447          216
# 1028         VerHagen, Drew  4-Seam Fastball  0.004449          238
# 366               Gray, Jon  4-Seam Fastball  0.004468          754
# 700            Muller, Kyle  4-Seam Fastball  0.004469          442
# 599             Lynn, Lance           Sinker  0.004567          280
# 548          Lambert, Peter  4-Seam Fastball  0.004574          432
# 454           Hunter, Tommy           Sinker  0.004579          136
# 103           Bradish, Kyle  4-Seam Fastball  0.004579          483
# 590              Lugo, Seth  4-Seam Fastball  0.004593          517
# 129      Bumgarner, Madison  4-Seam Fastball  0.004599          116
# 953         Stripling, Ross  4-Seam Fastball  0.004614          277
# 1000       Toussaint, Touki  4-Seam Fastball  0.004619          254
# 594           Lyles, Jordan  4-Seam Fastball  0.004645          680
# 704           Musgrove, Joe  4-Seam Fastball  0.004711          384
# 885        Scholtens, Jesse  4-Seam Fastball  0.004727          370
# 800          Quantrill, Cal           Sinker  0.004743          529
# 307              Fried, Max  4-Seam Fastball  0.004785          202
# 940          Steele, Justin  4-Seam Fastball  0.004789         1161
# 571             Lively, Ben           Sinker  0.004803          226
# 352          Gomber, Austin  4-Seam Fastball  0.004815          853
# 44            Assad, Javier           Sinker  0.004831          276
# 211            Covey, Dylan           Sinker  0.004847          185
# 798           Pérez, Martín           Sinker  0.004851          718
# 934            Speier, Gabe  4-Seam Fastball  0.004853          108
# 494            Keller, Brad  4-Seam Fastball  0.004856          252
# 831      Rodriguez, Eduardo           Sinker  0.004884          152
# 104           Bradish, Kyle           Sinker  0.004904          363
# 245           Detmers, Reid  4-Seam Fastball  0.004909          803
# 1070            Wentz, Joey  4-Seam Fastball  0.004917          620
# 21         Alexander, Scott           Sinker  0.004944          389
# 330        Garrett, Braxton  4-Seam Fastball  0.004962          121
# 1039         Wacha, Michael           Sinker  0.004992          182
# 553             Lauer, Eric  4-Seam Fastball  0.005016          335
# 373           Greinke, Zack           Sinker  0.005019          264
# 1071       Wesneski, Hayden  4-Seam Fastball  0.005037          326
# 224           Cueto, Johnny  4-Seam Fastball  0.005052          201
# 153           Carlton, Drew  4-Seam Fastball  0.005061          160
# 924         Soriano, George  4-Seam Fastball  0.005084          252
# 403         Hendricks, Kyle  4-Seam Fastball  0.005103          312
# 438           Holton, Tyler           Sinker  0.005115          101
# 803          Quintana, José  4-Seam Fastball  0.005120          126
# 566     Liberatore, Matthew           Sinker  0.005128          134
# 424              Hill, Rich  4-Seam Fastball  0.005155          723
# 974       Syndergaard, Noah           Sinker  0.005177          307
# 437           Holton, Tyler  4-Seam Fastball  0.005209          255
# 771         Peterson, David  4-Seam Fastball  0.005218          330
# 786         Priester, Quinn  4-Seam Fastball  0.005220          101
# 683               Moll, Sam  4-Seam Fastball  0.005241          130
# 89               Bird, Jake           Sinker  0.005266          662
# 205           Cosgrove, Tom  4-Seam Fastball  0.005268          134
# 781            Plesac, Zach  4-Seam Fastball  0.005290          146
# 487       Kaprielian, James  4-Seam Fastball  0.005310          451
# 588          Lucchesi, Joey           Sinker  0.005377          156
# 627          Martinez, Seth  4-Seam Fastball  0.005408          287
# 1029         VerHagen, Drew           Sinker  0.005412          133
# 76            Bello, Brayan  4-Seam Fastball  0.005422          400
# 367            Gray, Josiah  4-Seam Fastball  0.005427          459
# 965            Suter, Brent  4-Seam Fastball  0.005442          256
# 532              Koch, Matt  4-Seam Fastball  0.005456          122
# 916             Smith, Will  4-Seam Fastball  0.005479          263
# 169          Chafin, Andrew  4-Seam Fastball  0.005490          120
# 45             Avila, Pedro  4-Seam Fastball  0.005500          115
# 91          Blackburn, Paul  4-Seam Fastball  0.005529          191
# 852          Rucinski, Drew  4-Seam Fastball  0.005531          101
# 372           Greinke, Zack  4-Seam Fastball  0.005602          439
# 565     Liberatore, Matthew  4-Seam Fastball  0.005642          290
# 249             Dodd, Dylan  4-Seam Fastball  0.005652          201
# 120            Brito, Jhony  4-Seam Fastball  0.005736          164
# 447          Hudson, Dakota  4-Seam Fastball  0.005752          121
# 817              Rea, Colin  4-Seam Fastball  0.005762          335
# 563        Leiter Jr., Mark           Sinker  0.005768          254
# 35           Anderson, Nick  4-Seam Fastball  0.005772          265
# 443          Houser, Adrian  4-Seam Fastball  0.005805          348
# 966            Suter, Brent           Sinker  0.005831          248
# 413         Hernandez, Jose  4-Seam Fastball  0.005838          197
# 385           Harris, Hobie  4-Seam Fastball  0.005841          121
# 595           Lyles, Jordan           Sinker  0.005855          220
# 607            Maeda, Kenta  4-Seam Fastball  0.005857          262
# 912         Smeltzer, Devin  4-Seam Fastball  0.005861          112
# 459             Irvin, Cole           Sinker  0.005883          173
# 383              Hand, Brad  4-Seam Fastball  0.005948          238
# 148        Canning, Griffin  4-Seam Fastball  0.005955          483
# 1084       Williams, Trevor  4-Seam Fastball  0.005972          964
# 306          Freeland, Kyle           Sinker  0.005976          516
# 1118        Yarbrough, Ryan           Sinker  0.005990          282
# 370             Gray, Sonny           Sinker  0.005999          338
# 503          Kelly, Merrill  4-Seam Fastball  0.006026          544
# 1101         Wittgren, Nick  4-Seam Fastball  0.006047          170
# 87          Bielak, Brandon  4-Seam Fastball  0.006072          368
# 869       Sandoval, Patrick  4-Seam Fastball  0.006105          471
# 411           Herget, Kevin  4-Seam Fastball  0.006121          171
# 183           Civale, Aaron           Sinker  0.006185          241
# 448          Hudson, Dakota           Sinker  0.006203          252
# 355         Gonzales, Marco  4-Seam Fastball  0.006210          297
# 956         Stroman, Marcus           Sinker  0.006236          882
# 903          Shreve, Chasen  4-Seam Fastball  0.006250          252
# 804          Quintana, José           Sinker  0.006276          133
# 270          Englert, Mason  4-Seam Fastball  0.006285          284
# 712            Naile, James           Sinker  0.006289          136
# 1109         Woodford, Jake           Sinker  0.006291          352
# 892               Sears, JP  4-Seam Fastball  0.006304         1096
# 630             Maton, Phil  4-Seam Fastball  0.006334          263
# 404         Hendricks, Kyle           Sinker  0.006345          522
# 88          Bielak, Brandon           Sinker  0.006386          282
# 973       Syndergaard, Noah  4-Seam Fastball  0.006393          182
# 918             Smyly, Drew           Sinker  0.006439          808
# 284            Farmer, Buck  4-Seam Fastball  0.006457          375
# 92          Blackburn, Paul           Sinker  0.006460          267
# 955         Stroman, Marcus  4-Seam Fastball  0.006519          156
# 1041       Wainwright, Adam           Sinker  0.006530          395
# 787         Priester, Quinn           Sinker  0.006567          171
# 830      Rodriguez, Eduardo  4-Seam Fastball  0.006578          675
# 74             Beeks, Jalen  4-Seam Fastball  0.006592          287
# 788          Pruitt, Austin  4-Seam Fastball  0.006619          190
# 891         Seabold, Connor  4-Seam Fastball  0.006635          797
# 155        Carrasco, Carlos  4-Seam Fastball  0.006640          482
# 458             Irvin, Cole  4-Seam Fastball  0.006700          280
# 1086    Williamson, Brandon  4-Seam Fastball  0.006753          475
# 354          Gonsolin, Tony  4-Seam Fastball  0.006807          610
# 719            Nelson, Kyle  4-Seam Fastball  0.006836          199
# 31          Anderson, Chase  4-Seam Fastball  0.006907          288
# 65           Bassitt, Chris  4-Seam Fastball  0.006979          249
# 406            Henry, Tommy  4-Seam Fastball  0.007027          681
# 233            Davies, Zach  4-Seam Fastball  0.007073          186
# 199         Corbin, Patrick  4-Seam Fastball  0.007182          355
# 995          Thompson, Zack  4-Seam Fastball  0.007195          235
# 870       Sandoval, Patrick           Sinker  0.007380          184
# 305          Freeland, Kyle  4-Seam Fastball  0.007402          360
# 269            Elder, Bryce           Sinker  0.007493          870
# 570             Lively, Ben  4-Seam Fastball  0.007516          380
# 268            Elder, Bryce  4-Seam Fastball  0.007825          268
# 969          Suárez, Ranger  4-Seam Fastball  0.007896          324
# 904          Shuster, Jared  4-Seam Fastball  0.008559          319
# 954         Stripling, Ross           Sinker  0.008573          103
# 167             Cessa, Luis  4-Seam Fastball  0.009156          109
#
#             velo  perceived_velo    spin_rate  vert_break  horz_break  \
# 69     99.537519       99.854709   2416.92093    1.711798    0.568372
# 401    99.671946      100.080353  2660.669683     1.54629    0.277421
# 278    98.770769       99.321649  2441.789744    1.585795    0.144564
# 952    97.220351       98.405392  2365.819912    1.544451    0.478887
# 847    96.690323       98.987294  2339.473118    1.462581    0.376129
# 171    99.152128      100.491170  2436.154255     1.50266    0.389016
# 275     95.71206       96.121021  2285.201005    1.669548    0.291055
# 794    97.671888       98.589609  2637.040773    1.492554    0.717725
# 377    96.035094       96.710271  2145.184906    1.565245    0.624566
# 151    96.096214       95.268916  2119.688196   -0.227506    1.487862
# 1129      98.775       99.497913  2550.515957     1.47266    0.730479
# 780    94.443109       95.353563  2334.030871     1.67387    0.329261
# 921     95.33657       96.185927  2424.208711    1.568149    0.393793
# 752    98.284932       99.466892   2361.10274     1.39274     0.81226
# 670    98.273232       98.673624  2373.237374    1.438333    0.654848
# 107    96.174024       96.144638  2311.324278    1.593531    0.405076
# ...
# 386   0.086963     6.049664  101.298294
# 856   0.087120     6.049506  101.295662
# 975   0.089119     6.047507  101.262199
# 543   0.089905     6.046721  101.249039
# 572   0.090965     6.045661  101.231277
# 603   0.091749     6.044878  101.218163
# 610   0.092414     6.044212  101.207016
# 1095  0.092720     6.043906  101.201889
# 1084  0.597245     5.539381   92.753899
# 306   0.597589     5.539037   92.748138
# 1118  0.598972     5.537654   92.724976
# 370   0.599881     5.536746   92.709770
# 503   0.602564     5.534062   92.664833
# 1101  0.604743     5.531883   92.628342
# 87    0.607226     5.529401   92.586784
# 869   0.610480     5.526146   92.532280
# 411   0.612066     5.524560   92.505730
# 183   0.618470     5.518156   92.398499
# 448   0.620289     5.516337   92.368050
# 355   0.621027     5.515599   92.355682
# 956   0.623617     5.513010   92.312325
# 903   0.624983     5.511643   92.289444
# 804   0.627598     5.509028   92.245659
# 270   0.628549     5.508078   92.229744
# 712   0.628870     5.507756   92.224358
# 1109  0.629104     5.507522   92.220436
# 892   0.630410     5.506217   92.198578
# 630   0.633435     5.503191   92.147919
# 404   0.634477     5.502149   92.130463
# 88    0.638633     5.497993   92.060890
# 973   0.639278     5.497348   92.050079
# 918   0.643869     5.492758   91.973213
# 284   0.645708     5.490918   91.942406
# 92    0.645979     5.490647   91.937881
# 955   0.651908     5.484718   91.838593
# 1041  0.653041     5.483585   91.819618
# 787   0.656722     5.479904   91.757988
# 830   0.657834     5.478792   91.739365
# 74    0.659163     5.477464   91.717133
# 788   0.661918     5.474708   91.670982
# 891   0.663503     5.473123   91.644440
# 155   0.663964     5.472662   91.636734
# 458   0.670010     5.466617   91.535500
# 1086  0.675343     5.461283   91.446182
# 354   0.680666     5.455960   91.357056
# 719   0.683576     5.453051   91.308342
# 31    0.690693     5.445933   91.189156
# 65    0.697860     5.438766   91.069160
# 406   0.702664     5.433962   90.988716
# 233   0.707275     5.429351   90.911514
# 199   0.718172     5.418454   90.729050
# 995   0.719500     5.417126   90.706810
# 870   0.738042     5.398584   90.396324
# 305   0.740156     5.396470   90.360931
# 269   0.749262     5.387364   90.208466
# 570   0.751566     5.385060   90.169884
# 268   0.782466     5.354160   89.652473
# 969   0.789620     5.347006   89.532692
# 904   0.855881     5.280745   88.423180
# 954   0.857251     5.279376   88.400253
# 167   0.915612     5.221014   87.423027

# %%
fl = pd.read_csv('../../AutomatedPitchTagging/AutoTaggedCSVs/autoMaster 2023-08-16.csv')

# %%
fl['RelSide'] = abs(fl['RelSide'])

# %%
arm_angles = np.degrees(np.arctan2(fl['RelHeight'], fl['RelSide']))
fl['arm_angle'] = arm_angles

# %%
fl = fl.rename(columns={'RelSpeed': 'release_speed', 'HorzBreak': 'pfx_x', 'InducedVertBreak': 'pfx_z', 'RelSide': 'release_pos_x', 'RelHeight': 'release_pos_z', 'Extension': 'release_extension', 'SpinRate': 'release_spin_rate', 'yt_Efficiency': 'normalized_spin_efficiency'})

# %%
average_extension = fl['release_extension'].mean()

extension_constant = (3.5/capps_constant)
def calculate_perceived_velocity_fl(row):
    adjusted_extension = row['release_extension'] - average_extension
    perceived_velocity = row['release_speed'] + (adjusted_extension * extension_constant)
    return perceived_velocity

fl['perceived_velocity'] = fl.apply(calculate_perceived_velocity_fl, axis=1)

# %%
def predict_pitch_fl(df, pitch_name, model):
    pitch_df = df[df['AutoPitchType'].isin(pitch_name)]
    pitch_df['xrv'] = model.predict(pitch_df[model.feature_names_in_])
    return pitch_df

fastball_fl = predict_pitch_fl(fl, ['Fastball', 'Sinker'], fb_model)
bb_fl = predict_pitch_fl(fl, ['Cutter', 'Slider', 'Curveball'], bb_model)
offs_fl = predict_pitch_fl(fl, ['Splitter', 'Changeup'], offs_model)

total_fl = pd.concat([fastball_fl, bb_fl, offs_fl])
# Out:
# C:\Users\kellyjc\AppData\Local\Temp\ipykernel_2152\2161729773.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pitch_df['xrv'] = model.predict(pitch_df[model.feature_names_in_])
# C:\Users\kellyjc\AppData\Local\Temp\ipykernel_2152\2161729773.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pitch_df['xrv'] = model.predict(pitch_df[model.feature_names_in_])
# C:\Users\kellyjc\AppData\Local\Temp\ipykernel_2152\2161729773.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pitch_df['xrv'] = model.predict(pitch_df[model.feature_names_in_])

# %%
def calculate_stuff_plus(pitch_fl, min_num_pitches=100):
    agg_stuff_plus = pitch_fl.groupby(['Pitcher', 'AutoPitchType']).agg(
        mean_xrv=('xrv', 'mean'),
        num_pitches=('Pitcher', 'count'),
        velo=('release_speed', 'mean'),
        perceived_velo=('perceived_velocity', 'mean'),
        spin_rate=('release_spin_rate', 'mean'),
        vert_break=('pfx_z', 'mean'),
        horz_break=('pfx_x', 'mean')
    ).reset_index()

    agg_stuff_plus['xrv_100'] = agg_stuff_plus['mean_xrv'] * 100
    agg_stuff_plus['xrv_100_adj'] = abs(agg_stuff_plus['xrv_100'] - agg_stuff_plus['xrv_100'].max())
    agg_stuff_plus['stuff+'] = (agg_stuff_plus['xrv_100_adj'] / agg_stuff_plus['xrv_100_adj'].mean()) * 100
    agg_stuff_plus = agg_stuff_plus.sort_values('stuff+', ascending=False)

    agg_stuff_plus = agg_stuff_plus[agg_stuff_plus['num_pitches'] > min_num_pitches]

    return agg_stuff_plus

def calculate_agg_stuff_plus(pitch_fl, min_num_pitches=100):
    agg_stuff_plus = pitch_fl.groupby(['Pitcher']).agg(
        mean_xrv=('xrv', 'mean'),
        num_pitches=('Pitcher', 'count'),
        velo=('release_speed', 'mean'),
        perceived_velo=('perceived_velocity', 'mean'),
        spin_rate=('release_spin_rate', 'mean'),
        vert_break=('pfx_z', 'mean'),
        horz_break=('pfx_x', 'mean')
    ).reset_index()

    agg_stuff_plus['xrv_100'] = agg_stuff_plus['mean_xrv'] * 100
    agg_stuff_plus['xrv_100_adj'] = abs(agg_stuff_plus['xrv_100'] - agg_stuff_plus['xrv_100'].max())
    agg_stuff_plus['stuff+'] = (agg_stuff_plus['xrv_100_adj'] / agg_stuff_plus['xrv_100_adj'].mean()) * 100
    agg_stuff_plus = agg_stuff_plus.sort_values('stuff+', ascending=False)

    agg_stuff_plus = agg_stuff_plus[agg_stuff_plus['num_pitches'] > min_num_pitches]

    return agg_stuff_plus

agg_fb_fl = calculate_stuff_plus(fastball_fl, 100)
agg_bb_fl = calculate_stuff_plus(bb_fl, 100)
agg_offs_fl = calculate_stuff_plus(offs_fl, 50)
agg_total_fl = calculate_agg_stuff_plus(total_fl, 700)

# %%
pd.set_option('display.max_rows', None)
agg_total_fl
# Out:
#                   Pitcher  mean_xrv  num_pitches       velo  perceived_velo  \
# 130        Darrien Ragins -0.010080          737  85.517161       86.345026
# 112             Cole Cook  0.025623         1378  82.029276       81.010320
# 101          Chris Burica  0.036652          806  79.518997       79.918591
# 220           Jhon Vargas  0.038990          865  82.474856       82.390607
# 384        Tim Holdgrafer  0.047558          891  84.707772       84.523191
# 375        Steven Fuentes  0.052844         1064  87.904080       88.372130
# 197       Jackson Hickert  0.058947         1159  84.978073       84.270083
# 353         Ruben Ramirez  0.059220          899  85.181188       85.359906
# 278            Luis Perez  0.059240         1057  87.682825       86.604247
# 251        Justin Watland  0.060746          840  83.396278       82.752919
# 432            Zach Smith  0.063559         1169  86.037066       86.169909
# 420         Yasel Santana  0.065078         1369  86.875739       86.860857
# 187     Hayden Shenefield  0.065892          940  85.492829       84.690991
# 31            Angelo Baez  0.066673         1162  84.118112       83.219451
# 90            Carlos Sano  0.067190         1228  85.852939       87.638035
# 178       Garrison Bryant  0.068018          728  84.811949       83.773002
# 424              Zac Ryan  0.068781          716  86.847537       89.502618
# 29           Andy Hammond  0.070983          832  85.102444       84.677118
# 343          Ricky Castro  0.071052          714  87.194734       86.667585
# 86        Cam Aufderheide  0.071910          850  85.515518       86.792013
# 321           Nick Garcia  0.071931          751  86.712591       86.728040
# 371      Stephen Chamblee  0.072777          831  83.997951       84.168625
# 228         Joey Gonzalez  0.074431         1275  84.436800       84.005844
# 125  Damon Casetta-stubbs  0.076753          820  87.115733       86.924529
# 328       Osman Gutierrez  0.076780         1285  87.863863       87.011918
# 116       Collin Sullivan  0.077037         1423  88.803457       89.433417
# 246             July Sosa  0.078067          883  83.852838       83.634115
# 355            Ryan Munoz  0.078088          967  77.639304       77.176105
# 195        Jack Dellinger  0.078275          777  84.272946       86.067091
# 148           Elijah Gill  0.078756         1126  84.162175       85.069553
